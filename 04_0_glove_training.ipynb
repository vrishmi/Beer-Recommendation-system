# %%
from gensim.models import KeyedVectors
from gensim.models import Word2Vec

# %%
#! Loading preprocessed reviews
with open("/corpus_/corpus_trimmed", "r") as f:
    cleaned = f.readlines()
len(cleaned)

# %%
cleaned[:4]
# Out:
# ['trying saris dark whilst sitting banks dunaj river bratislava beer deep dark amber foamy white head laced way glass smell slightly malty crazy taste burst sweet malt mouthfeel good lighter body good carbonation overall sweet good beer style worth try schawtzbier fans tap hotel restaurant stary smokovec slovakia served ari glass slight hourglass shape a: looks solid rootbeer float-type head 3 fingers toffee colored head gorgeous clumpy lacing opaque dark chocolate brown red hues edges shallow spots s: smokey chocolate coffee malts dominate nose t: actually delicious complex beer abv chocolate coffee pronounced taste dig m: low mid carb perfect thick overly coating palate wet faintly dry finish o: enjoyable beer find future huge fan style found good far on-tap whilst bratislava slovakia drank branded saris pint glass nice cola like black tan head small good retention lot better look standard pale lager opinion gives mild coffee barely smell contains hints caramel possibly nuts light vanilla similar taste smell sort mild guinness taste coffee barely main flavour burnt light bitter finish nice generally smooth heavy light medium drinkable nice beer smooth pleasant flavorful definitely try reminds lot guinness particularly taste department probably nicest beer tried whilst slovakia at: http: abarwithnoname wordpress com recollection dark slovak beer served fluffy foamy frothy thick tan head lasted lace color clear dark garnet aroma mild roasty dark malt little coffee cocoa fruit flavor sweetness reminds little black lager body tad light good carbonation finish like flavor short medium length easy drinking beer session beer homeland slovakia beer pours beautiful dark brown color great brown fluffy head disappeared fast thin lacing smell: beers type brew weak smell bit different beers type far best strongest smell roasted malts caramel strong coffee yeast taste: complex beers brewing style sweet hints chocolate dark roasted coffee malts present aftertaste pleasant bitter-sour dry mouthfeel: creamy smooth rolls tongue medium-low carbonation overall: best beer type brown beer style: good looks nice smell fine taste fantastic mouthfeel studying slovak language bottle girlfriend native speaker revealed artificial sweeteners added beer beer fully natural product enormous disappointment reason mind added artificial sweeteners beer try style bottle summer trip slovakia impressed arriving bratislava summer priority pint stuff tap compare dark euro lagers good beer nice head distinctive sweet smell overpowering taste complex smooth hint toffee drinkability great probably limit pint said tried beers similar tmavy saris compare currently favorite beers damn cheap bottle local super market zilina cost 70 cents poured bottle 0 5l branded staropramen mug appearance: beer looks nice dark cola-like look tan foamy head dissipates pretty quickly smell: smells malty hints nuts caramel definitely better-smelling beers slovakia taste: taste matches smell malty nutty definite caramel notes tastes like doppelbock mouthfeel: smooth smooth discernible carbonation feel drinkability: excellent brew currently slovakia drinking czech pilsners welcome break routine ari certainly brew dark beer start trying dark beers breweries tap 1 slovak pub bratislava appearance dark cola like beers style came 3 inches amber head fell fast heavy clumpy lacing aroma cola notes coffee licorice faint style known face complex flavors faint notes coffee cola licorice light body dark lager carbonation sits throat makes want belch drink fast leaves mouth teeth feeling coated sticky refreshing sessionable like good slovak beer inexpensive thirst quenching taste far saris eastern slovakia brewer dedicated address popular taste expect extraordinary hand completely wrong brews middle-of-the-road dark lager slovakian style relatively dry nice malts hints roasted notes good drinkabillity black color dark red reflexes brownish foam beautiful persistent falls leaving veil nose good coffee  ...
#  'pours clear fairly carbonated genuine amber half inch pale green head drops soon whitish traces little pips lacing pop inside glass aroma succinct caramel malt touch brown sugar general multi-tiered savory spice note tasting toasted caramel malt prominent followed soft dough note crisped vague esters soft honey sweetness breezes muted blend herbs spices assert bit laying rounded bitterness middle blip residual sweetness bows airy crispness lingers distant bitterness finish especially captivating reasonably interesting medium bodied creamy consistency somewhat flat presentation deadens end style knowledgeable worth try diversity sake likely choice choice sweetness oddly spiced character eminently drinkable absolutely worth try anticipating timely return a: pours orangey amber head bit visible sediment s: honey sweetness touch fruit t: honey banana flavours touch floral hops smooth honey-sweet flavour lingering finish unique delicious m: light creamy sligth touch carbonation smooth finish - feels like ate spoonful honey d: braggot fan style beer offers interesting taste experience enjoyable drink reccomend beer tried style - hands - worth money nice surprise find liquor store deal 2 50 bottle beer reminds overly sweet scottish ale lot flavour sweet taste like rock candy honey reminds mead beer like malty darkly fruity complex hints taste surprise good think took word mead label review bit higher considering beer mead surprised low alcohol content smell distinctly honey nature real notable attributes talk taste left desired higher alcohol content meads lift pallet real lack-thereof overall impression mead best date found label aging determine grow complexity overall impression decent smell notable mead ahead try certainly interesting possibly better czech beers classed braggot consider true mead like strong honey beer dark amber colour little head malt-honey scent faint hop presence bitter-sweet malt hop flavour powerful honey notes mead like honey beer tried certainly like mead carbonation come mead low alcohol content hops thin body enjoyable mead honey beer glad close mead government run liquor stores cool beer bc liqour stores tawny colour head sed nose sweetish old ale notes bottle noted mead based ale intial flavours suggested english old ale cellar honey subdued liked complexity flavours old fruit competed honey yeasty note finish different unlike ant czech beer appearance: head retention - murky fit pleasant red-gold hue dances light smell: fresh honey toast marshmallows graham wafers clover undercurrent flemish-like tartness surprising hit alcohol considering relatively low abv come singular aroma nice taste: fresh honey prominent expected mingles nicely gentle spiced character slight dose peppery alcohol long finish plenty candied sugar unpleasantly sweet grainy maltiness hold mouthfeel: thin bodiless unpleasant improved drinkability: pounding lot ever-so-slightly cloying course glass overall recommend giving shot little bit ordinary picked 4 3 07 drank 4 15 07 good aug 15 2007 5 6 abv according bottle slightly hazy ruby red fairly small white head dissipates thin rim foam interesting color expecting aroma light crisp notes cherry solid sweet malt backbone subdued hop presence somewhat citrusy floral litter way bitterness definitely honey cherry flavors chocolate metallic notes interesting lingering sweetness honey doesnt settle balanced crisp carbonation medium body finishes dry like wine drinkable sweet taste unforunately label czech cant read beer certainly cherries honey fruits spices great interesting worth try colour pale amber low white foam leaves lacing smell loaded honey lots honey kind like taste smell fine flavour natural honey body low notes malt aftertaste dominated honey-flavours hint bitterness carbonation mild big bubbles best honey-beer found far\n']

# %%
#! tokenizing them for training
cleaned = [i.split() for i in cleaned]

# %%
#! loading a pretrained model
glove_vectors =  KeyedVectors.load_word2vec_format(
    fname="glove_pretrained/glove.840B.300d.txt", 
    binary=False, no_header=True
)

# %%
#! creating base model class. Vector size should match that of pretrained vectors
base_model = Word2Vec(vector_size=300, min_count=5,epochs=15)
base_model.build_vocab(cleaned)
total_examples = base_model.corpus_count

# %%
#! add pretrained GloVe's vocabulary
base_model.build_vocab(list(glove_vectors.key_to_index.keys()), update=True)

# %%
from gensim.models.callbacks import CallbackAny2Vec

class callback(CallbackAny2Vec):
    '''Callback to print loss after each epoch.'''

    def __init__(self):
        self.epoch = 0
        self.loss_to_be_subed = 0

    def on_epoch_end(self, model):
        loss = model.get_latest_training_loss()
        loss_now = loss - self.loss_to_be_subed
        self.loss_to_be_subed = loss
        print('Loss after epoch {}: {}'.format(self.epoch, loss_now))
        self.epoch += 1

# %%
#! Training the model
base_model.train(
    cleaned,
    total_examples=total_examples,
    epochs=base_model.epochs,
    compute_loss=True,
    callbacks=[callback()],
)
base_model_wv = base_model.wv

# %% [markdown]
# ---
# ---
# ### Testing Models
# ---
# ---

# %%
md_840B = KeyedVectors.load("finetuned/glove.840B.300d.ft.model")
md_42B = KeyedVectors.load("finetuned/glove.42B.300d.ft.model")
md_6B = KeyedVectors.load("finetuned/glove.6B.200d.ft.model")

# %%
import pandas as pd

# %%
top = 20
word = "cheap"
_6b = pd.DataFrame(md_6B.wv.similar_by_key(word, topn=top), columns=["6b_word", "6b_similarity"])
_42b = pd.DataFrame(md_42B.wv.similar_by_key(word, topn=top), columns=["42b_word", "42b_similarity"])
_840b = pd.DataFrame(md_840B.wv.similar_by_key(word, topn=top), columns=["840b_word", "840b_similarity"])

pd.concat([_6b, _42b, _840b], axis= 1)
# Out:
#           6b_word  6b_similarity          42b_word  42b_similarity  \
# 0           cheep       0.769602             cheep        0.736627
# 1          crappy       0.722729            crappy        0.669794
# 2          shitty       0.716751            shitty        0.657957
# 3          cheapo       0.642173            cheapo        0.614901
# 4           swill       0.627762           cheaply        0.603771
# 5        horrible       0.611165          horrible        0.578439
# 6           nasty       0.606931             swill        0.571536
# 7         cheaply       0.606869             macro        0.563824
# 8          rotgut       0.595265             nasty        0.558905
# 9           macro       0.593115            rotgut        0.557519
# 10       gasoline       0.587330          cheapest        0.555001
# 11       terrible       0.575975            budget        0.546028
# 12  non-alcoholic       0.573444           cheaper        0.545826
# 13          awful       0.569388        industrial        0.542220
# 14       lakeport       0.565412       inexpensive        0.539733
# 15         budget       0.555998       low-quality        0.531673
# 16     industrial       0.555897         budweiser        0.531437
# 17  mass-produced       0.555895          terrible        0.530647
# 18         adjuct       0.553201         low-grade        0.528497
# 19      budweiser       0.552057  eastern-european        0.523604
#
#       840b_word  840b_similarity
# 0         cheep         0.710659
# 1        crappy         0.684083
# 2      horrible         0.614213
# 3        shitty         0.611913
# 4         swill         0.592604
# 5        cheapo         0.592304
# 6         macro         0.575125
# 7      terrible         0.573023
# 8         awful         0.570081
# 9         nasty         0.569548
# 10      cheaply         0.554383
# 11     cheapest         0.546130
# 12      cheaper         0.543288
# 13       budget         0.533467
# 14         crap         0.533148
# 15    budweiser         0.528200
# 16  inexpensive         0.527812
# 17       rotgut         0.523032
# 18      garbage         0.512271
# 19        worse         0.510252
