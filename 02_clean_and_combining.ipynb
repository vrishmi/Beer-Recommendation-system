# %% [markdown]
# ---
# ---
#
# # Cleaning, Casting & Merging
#
# ---
# ---

# %%
import pandas as pd
import numpy as np
import fastparquet as fpq
import re

# %% [markdown]
# ---
#
# # Ratebeer
#
# ---

# %%
df_rb = pd.read_parquet("./ratebeer.parquet", engine="fastparquet")

# %%
df_rb
# Out:
#                                   beer/name beer/beerId beer/brewerId  \
# 0                  John Harvards Simcoe IPA       63836          8481
# 1                  John Harvards Simcoe IPA       63836          8481
# 2             John Harvards Cristal Pilsner       71716          8481
# 3        John Harvards Fancy Lawnmower Beer       64125          8481
# 4        John Harvards Fancy Lawnmower Beer       64125          8481
# ...                                     ...         ...           ...
# 2924158              Oakhill Mendip Twister       12240          1028
# 2924159      Oakhill Yeoman 1767 Strong Ale        5677          1028
# 2924160      Oakhill Yeoman 1767 Strong Ale        5677          1028
# 2924161      Oakhill Yeoman 1767 Strong Ale        5677          1028
# 2924162      Oakhill Yeoman 1767 Strong Ale        5677          1028
#
#         beer/ABV                    beer/style review/appearance review/aroma  \
# 0            5.4  India Pale Ale &#40;IPA&#41;               4/5         6/10
# 1            5.4  India Pale Ale &#40;IPA&#41;               4/5         6/10
# 2              5             Bohemian Pilsener               4/5         5/10
# 3            5.4                         Klsch               2/5         4/10
# 4            5.4                         Klsch               2/5         4/10
# ...          ...                           ...               ...          ...
# 2924158      6.3                         Stout               3/5         7/10
# 2924159        5            Premium Bitter/ESB               4/5         5/10
# 2924160        5            Premium Bitter/ESB               4/5         4/10
# 2924161        5            Premium Bitter/ESB               3/5         5/10
# 2924162        5            Premium Bitter/ESB               4/5         8/10
#
#         review/palate review/taste review/overall review/time  \
# 0                 3/5         6/10          13/20  1157587200
# 1                 4/5         7/10          13/20  1157241600
# 2                 3/5         6/10          14/20   958694400
# 3                 2/5         4/10           8/20  1157587200
# 4                 2/5         4/10           8/20  1157587200
# ...               ...          ...            ...         ...
# 2924158           3/5         7/10          15/20  1013731200
# 2924159           3/5         6/10          12/20  1074816000
# 2924160           3/5         6/10          13/20  1050796800
# 2924161           2/5         5/10          10/20  1016409600
# 2924162           4/5         7/10          15/20  1000252800
#
#         review/profileName                                        review/text
# 0                   hopdog  On tap at the Springfield, PA location. Poured...
# 1             TomDecapolis  On tap at the John Harvards in Springfield PA....
# 2           PhillyBeer2112  UPDATED: FEB 19, 2003 Springfield, PA. I've ne...
# 3             TomDecapolis  On tap the Springfield PA location billed as t...
# 4                   hopdog  On tap at the Springfield, PA location. Poured...
# ...                    ...                                                ...
# 2924158          rauchbier  Doesnt suggest it from the bottle label, but f...
# 2924159       imdownthepub  Cask conditioned at The Wild Goose, Combeignte...
# 2924160           SilkTork  The original Oakhill Brewery was formed in 176...
# 2924161             omhper  Sampled cask conditioned. Amber coloured. Frui...
# 2924162                Bov
#
# [2924163 rows x 13 columns]

# %%
for col in ("review/appearance","review/aroma","review/palate","review/taste","review/overall"):
    df_rb[col] = df_rb[col].apply(lambda x: float(x.split("/")[0]))

# %%
#! Scaling all the features to range 0-5

df_rb['review/aroma'] /= 2
df_rb['review/taste'] /= 2
df_rb['review/overall'] /= 4

# %%
#! Converting ABV to numberic and filling non-numeric values with NaN
df_rb['beer/ABV'] = pd.to_numeric(df_rb['beer/ABV'], errors='coerce')
df_rb['review/time'] = pd.to_datetime(df_rb['review/time'].astype(np.int64), unit='s', cache=True)
df_rb['review/site'] = "RateBeer"

# %%
df_rb.describe()
# Out:
#            beer/ABV  review/appearance  review/aroma  review/palate  \
# count  2.785526e+06       2.924163e+06  2.924163e+06   2.924163e+06
# mean   6.640794e+00       3.432027e+00  3.176804e+00   3.257236e+00
# min    1.000000e-02       1.000000e+00  5.000000e-01   1.000000e+00
# 25%    5.000000e+00       3.000000e+00  3.000000e+00   3.000000e+00
# 50%    6.000000e+00       3.000000e+00  3.500000e+00   3.000000e+00
# 75%    8.000000e+00       4.000000e+00  3.500000e+00   4.000000e+00
# max    5.770000e+01       5.000000e+00  5.000000e+00   5.000000e+00
# std    2.313753e+00       8.125569e-01  8.195824e-01   8.297312e-01
#
#        review/taste  review/overall                    review/time
# count  2.924163e+06    2.924163e+06                        2924163
# mean   3.225964e+00    3.299924e+00  2008-03-08 16:15:45.885438976
# min    5.000000e-01    2.500000e-01            2000-04-12 00:00:00
# 25%    3.000000e+00    3.000000e+00            2006-05-24 00:00:00
# 50%    3.500000e+00    3.500000e+00            2008-07-08 00:00:00
# 75%    4.000000e+00    3.750000e+00            2010-05-09 00:00:00
# max    5.000000e+00    5.000000e+00            2012-01-13 00:00:00
# std    8.114442e-01    8.381448e-01                            NaN

# %%
df_rb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2924163 entries, 0 to 2924162
# Data columns (total 14 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   beer/name           object
#  1   beer/beerId         object
#  2   beer/brewerId       object
#  3   beer/ABV            float64
#  4   beer/style          object
#  5   review/appearance   float64
#  6   review/aroma        float64
#  7   review/palate       float64
#  8   review/taste        float64
#  9   review/overall      float64
#  10  review/time         datetime64[ns]
#  11  review/profileName  object
#  12  review/text         object
#  13  review/site         object
# dtypes: datetime64[ns](1), float64(6), object(7)
# memory usage: 312.3+ MB

# %%
(df_rb.count()/len(df_rb)*100).sort_values(ascending=True)
# Out:
# beer/ABV               95.258917
# beer/name             100.000000
# beer/beerId           100.000000
# beer/brewerId         100.000000
# beer/style            100.000000
# review/appearance     100.000000
# review/aroma          100.000000
# review/palate         100.000000
# review/taste          100.000000
# review/overall        100.000000
# review/time           100.000000
# review/profileName    100.000000
# review/text           100.000000
# review/site           100.000000
# dtype: float64

# %%
df_rb.to_parquet("./ratebeer_clean.parquet", engine="fastparquet")

# %% [markdown]
# ---
#
# # Beeradvocate
#
# ---

# %%
df_ba= pd.read_parquet("./beeradvocate.parquet", engine="fastparquet")

# %%
df_ba.describe()
# Out:
#             beer/name beer/beerId beer/brewerId beer/ABV    beer/style  \
# count         1586614     1586614       1586614  1586614       1586614
# unique          56857       66055          5840      531           104
# top     90 Minute IPA        2093            35     5.00  American IPA
# freq             3290        3290         39444   109144        117586
#
#        review/appearance review/aroma review/palate review/taste  \
# count            1586614      1586614       1586614      1586614
# unique                10            9             9            9
# top                    4            4             4            4
# freq              674186       557383        606711       541429
#
#        review/overall review/time review/profileName review/text
# count         1586614     1586614            1586614     1586614
# unique             10     1577960              33388     1585261
# top                 4  1101772800     northyorksammy
# freq           582764          21               5817         353

# %%
df_ba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1586614 entries, 0 to 1586613
# Data columns (total 13 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   beer/name           1586614 non-null  object
#  1   beer/beerId         1586614 non-null  object
#  2   beer/brewerId       1586614 non-null  object
#  3   beer/ABV            1586614 non-null  object
#  4   beer/style          1586614 non-null  object
#  5   review/appearance   1586614 non-null  object
#  6   review/aroma        1586614 non-null  object
#  7   review/palate       1586614 non-null  object
#  8   review/taste        1586614 non-null  object
#  9   review/overall      1586614 non-null  object
#  10  review/time         1586614 non-null  object
#  11  review/profileName  1586614 non-null  object
#  12  review/text         1586614 non-null  object
# dtypes: object(13)
# memory usage: 157.4+ MB

# %%
df_ba['beer/ABV'] = pd.to_numeric(df_ba['beer/ABV'], errors='coerce')
df_ba['review/time'] = pd.to_datetime(df_ba['review/time'].astype(np.int64), unit='s', cache=True)
df_ba['review/site'] = "BeerAdvocate"

# %%
for col in ("review/appearance","review/aroma","review/palate","review/taste","review/overall"):
    df_ba[col] = df_ba[col].astype(np.float64)

# %%
df_ba.describe()
# Out:
#            beer/ABV  review/appearance  review/aroma  review/palate  \
# count  1.518829e+06       1.586614e+06  1.586614e+06   1.586614e+06
# mean   7.042387e+00       3.841642e+00  3.735636e+00   3.743701e+00
# min    1.000000e-02       0.000000e+00  1.000000e+00   1.000000e+00
# 25%    5.200000e+00       3.500000e+00  3.500000e+00   3.500000e+00
# 50%    6.500000e+00       4.000000e+00  4.000000e+00   4.000000e+00
# 75%    8.500000e+00       4.000000e+00  4.000000e+00   4.000000e+00
# max    5.770000e+01       5.000000e+00  5.000000e+00   5.000000e+00
# std    2.322526e+00       6.160928e-01  6.976167e-01   6.822184e-01
#
#        review/taste  review/overall                    review/time
# count  1.586614e+06    1.586614e+06                        1586614
# mean   3.792860e+00    3.815581e+00  2008-10-15 16:48:00.012210944
# min    1.000000e+00    0.000000e+00            1996-08-22 00:00:01
# 25%    3.500000e+00    3.500000e+00  2007-03-06 23:36:28.249999872
# 50%    4.000000e+00    4.000000e+00     2009-04-08 15:01:21.500000
# 75%    4.500000e+00    4.500000e+00  2010-10-31 23:40:05.249999872
# max    5.000000e+00    5.000000e+00            2012-01-11 12:35:48
# std    7.319696e-01    7.206219e-01                            NaN

# %%
df_ba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1586614 entries, 0 to 1586613
# Data columns (total 14 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   beer/name           1586614 non-null  object
#  1   beer/beerId         1586614 non-null  object
#  2   beer/brewerId       1586614 non-null  object
#  3   beer/ABV            1518829 non-null  float64
#  4   beer/style          1586614 non-null  object
#  5   review/appearance   1586614 non-null  float64
#  6   review/aroma        1586614 non-null  float64
#  7   review/palate       1586614 non-null  float64
#  8   review/taste        1586614 non-null  float64
#  9   review/overall      1586614 non-null  float64
#  10  review/time         1586614 non-null  datetime64[ns]
#  11  review/profileName  1586614 non-null  object
#  12  review/text         1586614 non-null  object
#  13  review/site         1586614 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(7)
# memory usage: 169.5+ MB

# %%
(df_ba.count()/len(df_ba)*100).sort_values(ascending=True)
# Out:
# beer/ABV               95.727694
# beer/name             100.000000
# beer/beerId           100.000000
# beer/brewerId         100.000000
# beer/style            100.000000
# review/appearance     100.000000
# review/aroma          100.000000
# review/palate         100.000000
# review/taste          100.000000
# review/overall        100.000000
# review/time           100.000000
# review/profileName    100.000000
# review/text           100.000000
# review/site           100.000000
# dtype: float64

# %%
df_ba.to_parquet("./beeradvocate_clean.parquet", engine="fastparquet")

# %% [markdown]
# ---
#
# ## Combining the two
#
# ---

# %%
df = pd.concat([df_rb, df_ba], axis=0, ignore_index=True)

# %%
np.round(df.describe(), decimals=3)
# Out:
#           beer/ABV  review/appearance  review/aroma  review/palate  \
# count  4304355.000        4510777.000   4510777.000    4510777.000
# mean         6.782              3.576         3.373          3.428
# min          0.010              0.000         0.500          1.000
# 25%          5.000              3.000         3.000          3.000
# 50%          6.000              4.000         3.500          3.500
# 75%          8.000              4.000         4.000          4.000
# max         57.700              5.000         5.000          5.000
# std          2.325              0.774         0.823          0.815
#
#        review/taste  review/overall                    review/time
# count   4510777.000     4510777.000                        4510777
# mean          3.425           3.481  2008-05-25 10:04:22.078417920
# min           0.500           0.000            1996-08-22 00:00:01
# 25%           3.000           3.000            2006-08-30 00:00:00
# 50%           3.500           3.500            2008-10-21 23:04:11
# 75%           4.000           4.000            2010-07-23 00:00:00
# max           5.000           5.000            2012-01-13 00:00:00
# std           0.830           0.836                            NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4510777 entries, 0 to 4510776
# Data columns (total 14 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   beer/name           object
#  1   beer/beerId         object
#  2   beer/brewerId       object
#  3   beer/ABV            float64
#  4   beer/style          object
#  5   review/appearance   float64
#  6   review/aroma        float64
#  7   review/palate       float64
#  8   review/taste        float64
#  9   review/overall      float64
#  10  review/time         datetime64[ns]
#  11  review/profileName  object
#  12  review/text         object
#  13  review/site         object
# dtypes: datetime64[ns](1), float64(6), object(7)
# memory usage: 481.8+ MB

# %%
#! Percentage of non-null values in each column

(df.count()/len(df)*100).sort_values(ascending=True)
# Out:
# beer/ABV               95.423804
# beer/name             100.000000
# beer/beerId           100.000000
# beer/brewerId         100.000000
# beer/style            100.000000
# review/appearance     100.000000
# review/aroma          100.000000
# review/palate         100.000000
# review/taste          100.000000
# review/overall        100.000000
# review/time           100.000000
# review/profileName    100.000000
# review/text           100.000000
# review/site           100.000000
# dtype: float64

# %%
df[df['beer/ABV'].isna()]
# Out:
#                                                  beer/name beer/beerId  \
# 5                 John Harvards Vanilla Black Velvet Stout       31544
# 6                         John Harvards American Brown Ale       71714
# 11                                John Harvards Cassis Wit        1470
# 23       Barley Island Dirty &quot;Old&quot; Helen Sour...      114513
# 24       Barley Island Dirty &quot;Old&quot; Helen Sour...      114513
# ...                                                    ...         ...
# 4510749                                       Brandy Brown       45508
# 4510750                                            Maibock       36555
# 4510759                                      Resolution #2       48360
# 4510760                                      Resolution #2       48360
# 4510761                                      Resolution #2       48360
#
#         beer/brewerId  beer/ABV                       beer/style  \
# 5                8481       NaN                      Sweet Stout
# 6                8481       NaN                        Brown Ale
# 11               8481       NaN  Belgian White &#40;Witbier&#41;
# 23               3228       NaN                Sour Ale/Wild Ale
# 24               3228       NaN                Sour Ale/Wild Ale
# ...               ...       ...                              ...
# 4510749         14359       NaN               American Brown Ale
# 4510750         14359       NaN            Maibock / Helles Bock
# 4510759         14359       NaN          Belgian Strong Pale Ale
# 4510760         14359       NaN          Belgian Strong Pale Ale
# 4510761         14359       NaN          Belgian Strong Pale Ale
#
#          review/appearance  review/aroma  review/palate  review/taste  \
# 5                      5.0           4.0            4.0           3.5
# 6                      4.0           2.5            3.0           3.0
# 11                     3.0           2.5            3.0           3.5
# 23                     4.0           3.5            3.0           3.0
# 24                     4.0           3.5            3.0           3.0
# ...                    ...           ...            ...           ...
# 4510749                4.0           3.5            2.5           2.5
# 4510750                4.0           4.5            4.5           4.0
# 4510759                5.0           3.0            4.0           3.5
# 4510760                4.0           4.5            4.0           4.0
# 4510761                3.5           4.0            4.0           4.5
#
#          review/overall         review/time review/profileName  \
# 5                  4.00 2004-02-26 00:00:00           egajdzis
# 6                  3.00 2007-04-09 00:00:00             hopdog
# 11                 3.50 2000-05-19 00:00:00     PhillyBeer2112
# 23                 3.25 2010-05-14 00:00:00            fiulijn
# 24                 3.25 2010-05-03 00:00:00           Ungstrup
# ...                 ...                 ...                ...
# 4510749            3.00 2008-10-21 17:22:51             kasper
# 4510750            3.50 2007-04-29 10:22:48                BBM
# 4510759            4.00 2010-10-24 20:11:07         hoppymcgee
# 4510760            4.50 2009-05-09 21:57:03             WesWes
# 4510761            4.00 2009-03-08 22:07:00          Slatetank
#
#                                                review/text   review/site
# 5        Springfield, PA location... Poured an opaque b...      RateBeer
# 6        On tap at the Springfield, PA location. Listed...      RateBeer
# 11       UPDATED: FEB 19, 2003 Springfield, PA. Interes...      RateBeer
# 23       Courtesy of Kim, handbottledCloudy amber color...      RateBeer
# 24       Handbottled. A dark amber beer with a white he...      RateBeer
# ...                                                    ...           ...
# 4510749  Notes from cask sampled at Blind Tiger in May....  BeerAdvocate
# 4510750  I hadn't heard of Defiant before trying this b...  BeerAdvocate
# 4510759  Had on tap at Bierkraft in Brooklyn, NY. Poure...  BeerAdvocate
# 4510760  The beer pours a hazy gold color with a thick ...  BeerAdvocate
# 4510761  I shared this 750ml bottle with octopus87 @ th...  BeerAdvocate
#
# [206422 rows x 14 columns]

# %% [markdown]
# ### Removing non english & gibberish reviews
#
# ```Python
#
# # Code was executed on Kaggle for 4 hours
# # Removing non-english & gibberish reviews
#
# from langdetect import detect, lang_detect_exception
# from time import time
# non_eng = []
# gibberish = []
# n = len(df)
# count = 0
# start = time()
# for index, review in enumerate(df['review/text']):
#     tr = round((time()-start)*n/((index+1)*60),4)
#     try:
#         lang = detect(review)
#     except lang_detect_exception.LangDetectException:
#         gibberish.append((index,review))
#         count +=1
#         print("GIBBERISH: <start>", review, "<end>")
#         continue
#     if  lang != 'en':
#         non_eng.append((index,review))
#         count += 1
#         print(f"ET: {tr:>8} mins |", lang, f"| [{index}]",f"[{round(count/index*100,3)}%]", review[:150] )
# ```

# %%
with open("./utils/useless_non_eng", "r") as f:
    non_eng = [int(i) for i in f.readlines()]
with open("./utils/useless_gibberish", "r") as f:
    gibberish = [int(i) for i in f.readlines()]

useless_index = non_eng + gibberish

# %%
len(useless_index)
# Out:
# 46288

# %%
df = df.drop(useless_index).reset_index(drop=True)

# %%
df
# Out:
#                                   beer/name beer/beerId beer/brewerId  \
# 0                  John Harvards Simcoe IPA       63836          8481
# 1                  John Harvards Simcoe IPA       63836          8481
# 2             John Harvards Cristal Pilsner       71716          8481
# 3        John Harvards Fancy Lawnmower Beer       64125          8481
# 4        John Harvards Fancy Lawnmower Beer       64125          8481
# ...                                     ...         ...           ...
# 4464484                  The Horseman's Ale       33061         14359
# 4464485                  The Horseman's Ale       33061         14359
# 4464486                  The Horseman's Ale       33061         14359
# 4464487                  The Horseman's Ale       33061         14359
# 4464488                  The Horseman's Ale       33061         14359
#
#          beer/ABV                    beer/style  review/appearance  \
# 0             5.4  India Pale Ale &#40;IPA&#41;                4.0
# 1             5.4  India Pale Ale &#40;IPA&#41;                4.0
# 2             5.0             Bohemian Pilsener                4.0
# 3             5.4                         Klsch                2.0
# 4             5.4                         Klsch                2.0
# ...           ...                           ...                ...
# 4464484       5.2                   Pumpkin Ale                3.5
# 4464485       5.2                   Pumpkin Ale                2.5
# 4464486       5.2                   Pumpkin Ale                3.0
# 4464487       5.2                   Pumpkin Ale                4.5
# 4464488       5.2                   Pumpkin Ale                4.5
#
#          review/aroma  review/palate  review/taste  review/overall  \
# 0                 3.0            3.0           3.0            3.25
# 1                 3.0            4.0           3.5            3.25
# 2                 2.5            3.0           3.0            3.50
# 3                 2.0            2.0           2.0            2.00
# 4                 2.0            2.0           2.0            2.00
# ...               ...            ...           ...             ...
# 4464484           4.0            4.0           4.0            5.00
# 4464485           5.0            2.0           4.0            4.00
# 4464486           3.5            3.5           4.0            4.50
# 4464487           4.5            4.5           4.5            4.00
# 4464488           4.5            4.5           4.5            5.00
#
#                 review/time review/profileName  \
# 0       2006-09-07 00:00:00             hopdog
# 1       2006-09-03 00:00:00       TomDecapolis
# 2       2000-05-19 00:00:00     PhillyBeer2112
# 3       2006-09-07 00:00:00       TomDecapolis
# 4       2006-09-07 00:00:00             hopdog
# ...                     ...                ...
# 4464484 2006-11-05 00:01:32         maddogruss
# 4464485 2006-10-17 01:29:26          yelterdow
# 4464486 2006-10-13 01:21:53           TongoRad
# 4464487 2006-10-05 04:37:24           dherling
# 4464488 2006-10-04 23:41:59               cbl2
#
#                                                review/text   review/site  \
# 0        On tap at the Springfield, PA location. Poured...      RateBeer
# 1        On tap at the John Harvards in Springfield PA....      RateBeer
# 2        UPDATED: FEB 19, 2003 Springfield, PA. I've ne...      RateBeer
# 3        On tap the Springfield PA location billed as t...      RateBeer
# 4        On tap at the Springfield, PA location. Poured...      RateBeer
# ...                                                    ...           ...
# 4464484  If you're looking for a quality beer right alo...  BeerAdvocate
# 4464485  Growler fill from the long-awaited Defiant Bre...  BeerAdvocate
# 4464486  This was served from a growler and I suspect a...  BeerAdvocate
# 4464487  Ah, the horseman commeth. Cloudy chocolate bro...  BeerAdvocate
# 4464488  10/4/2006 $7.50 5.20% Fresh on tap.   Appearan...  BeerAdvocate
#
#               review/id
# 0              review_0
# 1              review_1
# 2              review_2
# 3              review_3
# 4              review_4
# ...                 ...
# 4464484  review_4464484
# 4464485  review_4464485
# 4464486  review_4464486
# 4464487  review_4464487
# 4464488  review_4464488
#
# [4464489 rows x 15 columns]

# %%
df['review/text'] = df['review/text'].apply(lambda text: re.sub(r'\s+', ' ', text))

# %%
df.to_parquet("./combined.parquet", engine="fastparquet", times="int96")
